# %%
import pandas as pd

# %%
df = pd.read_csv('USA_cars_datasets.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df.head(10)
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# 5           5   5700      dodge      mpv  2018  clean vehicle   45561.0
# 6           6   7300  chevrolet       pk  2010  clean vehicle  149050.0
# 7           7  13350        gmc     door  2017  clean vehicle   23525.0
# 8           8  14600  chevrolet   malibu  2018  clean vehicle    9371.0
# 9           9   5250       ford      mpv  2017  clean vehicle   63418.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# ...

# %%
df[:3]
# Out:
#    Unnamed: 0  price   brand    model  year   title_status   mileage   color  \
# 0           0   6300  toyota  cruiser  2008  clean vehicle  274117.0   black
# 1           1   2899    ford       se  2011  clean vehicle  190552.0  silver
# 2           2   5350   dodge      mpv  2018  clean vehicle   39590.0  silver
#
#                    vin        lot       state country     condition
# 0    jtezu11f88k007763  159348797  new jersey     usa  10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa   6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa   2 days left

# %%
df[["price","brand","model","year"]].to_csv("databaru.csv", index=False)

# %%
database = pd.read_csv("databaru.csv")

# %%
database.head()
# Out:
#    Unnamed: 0  price      brand    model  year
# 0           0   6300     toyota  cruiser  2008
# 1           1   2899       ford       se  2011
# 2           2   5350      dodge      mpv  2018
# 3           3  25000       ford     door  2014
# 4           4  27700  chevrolet     1500  2018

# %%
#menggabungkan dua data
df_head = df.head()
df_tail = df.tail()

# %%
df_head
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df_tail
# Out:
#       Unnamed: 0  price   brand  model  year   title_status  mileage   color  \
# 2494        2494   7800  nissan  versa  2019  clean vehicle  23609.0     red
# 2495        2495   9200  nissan  versa  2018  clean vehicle  34553.0  silver
# 2496        2496   9200  nissan  versa  2018  clean vehicle  31594.0  silver
# 2497        2497   9200  nissan  versa  2018  clean vehicle  32557.0   black
# 2498        2498   9200  nissan  versa  2018  clean vehicle  31371.0  silver
#
#                       vin        lot       state country      condition
# 2494    3n1cn7ap9kl880319  167722715  california     usa    1 days left
# 2495    3n1cn7ap5jl884088  167762225     florida     usa  21 hours left
# 2496    3n1cn7ap9jl884191  167762226     florida     usa  21 hours left
# 2497    3n1cn7ap3jl883263  167762227     florida     usa    2 days left
# 2498    3n1cn7ap4jl884311  167762228     florida     usa  21 hours left

# %%
df_concat = pd.concat([df_head,df_tail])
df_concat
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# 0      black    jtezu11f88k007763  159348797  new jersey     usa
# ...

# %%
#mereset index yg lama menjadi baru
df_concat = pd.concat([df_head,df_tail], ignore_index=True)
df_concat
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# 5        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 6        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 7        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 8        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 9        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# ...

# %%
#sorting data
df_concat.sort_values("year")
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# 6        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 7        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 8        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 9        2498   9200     nissan    versa  2018  clean vehicle   31371.0
# 5        2494   7800     nissan    versa  2019  clean vehicle   23609.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# ...

# %%
df_concat.sort_values("price", ascending=False)
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 6        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 7        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 8        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 9        2498   9200     nissan    versa  2018  clean vehicle   31371.0
# 5        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
#
#     color                  vin        lot       state country      condition
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left
# ...

# %%
df_head =  df.iloc[2:7]
df_head
# Out:
#    Unnamed: 0  price      brand model  year   title_status   mileage   color  \
# 2           2   5350      dodge   mpv  2018  clean vehicle   39590.0  silver
# 3           3  25000       ford  door  2014  clean vehicle   64146.0    blue
# 4           4  27700  chevrolet  1500  2018  clean vehicle    6654.0     red
# 5           5   5700      dodge   mpv  2018  clean vehicle   45561.0   white
# 6           6   7300  chevrolet    pk  2010  clean vehicle  149050.0   black
#
#                    vin        lot     state country      condition
# 2    3c4pdcgg5jt346413  167655728   georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855  virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266   florida     usa  22 hours left
# 5    2c4rdgeg9jr237989  167655771     texas     usa    2 days left
# 6    1gcsksea1az121133  167753872   georgia     usa  22 hours left

# %%
df
# Out:
#       Unnamed: 0  price      brand       model  year   title_status   mileage  \
# 0              0   6300     toyota     cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford          se  2011  clean vehicle  190552.0
# 2              2   5350      dodge         mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford        door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet        1500  2018  clean vehicle    6654.0
# 5              5   5700      dodge         mpv  2018  clean vehicle   45561.0
# 6              6   7300  chevrolet          pk  2010  clean vehicle  149050.0
# 7              7  13350        gmc        door  2017  clean vehicle   23525.0
# 8              8  14600  chevrolet      malibu  2018  clean vehicle    9371.0
# 9              9   5250       ford         mpv  2017  clean vehicle   63418.0
# 10            10  10400      dodge       coupe  2009  clean vehicle  107856.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df_concat.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
#drop kolom
databaru = df.drop(columns=["vin","lot","country"])
databaru
# Out:
#       Unnamed: 0  price      brand       model  year   title_status   mileage  \
# 0              0   6300     toyota     cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford          se  2011  clean vehicle  190552.0
# 2              2   5350      dodge         mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford        door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet        1500  2018  clean vehicle    6654.0
# 5              5   5700      dodge         mpv  2018  clean vehicle   45561.0
# 6              6   7300  chevrolet          pk  2010  clean vehicle  149050.0
# 7              7  13350        gmc        door  2017  clean vehicle   23525.0
# 8              8  14600  chevrolet      malibu  2018  clean vehicle    9371.0
# 9              9   5250       ford         mpv  2017  clean vehicle   63418.0
# 10            10  10400      dodge       coupe  2009  clean vehicle  107856.0
# ...

# %%
#mengambil berdasarkan colomn
df_concat["country"]
# Out:
# 0     usa
# 1     usa
# 2     usa
# 3     usa
# 4     usa
# 5     usa
# 6     usa
# 7     usa
# 8     usa
# 9     usa
# Name: country, dtype: object

# %%
databaru.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color       state      condition
# 0   black  new jersey   10 days left
# 1  silver   tennessee    6 days left
# 2  silver     georgia    2 days left
# 3    blue    virginia  22 hours left
# 4     red     florida  22 hours left

# %%
databaru.dtypes
# Out:
# Unnamed: 0        int64
# price             int64
# brand            object
# model            object
# year              int64
# title_status     object
# mileage         float64
# color            object
# state            object
# condition        object
# dtype: object

# %%
databari
